# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_silver/processing_zone/", True)
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.address_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.bins")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.customer_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.employee")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.inventory_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.order_items_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.orders_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.products_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.robots")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.shelves")

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_silver/processing_zone/", True)

# %%
dbutils.fs.ls("/Volumes/workspace/amazon_fullfilment_silver/processing_zone/")
