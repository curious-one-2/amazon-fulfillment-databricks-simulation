# %%
#cleanup source
dbutils.fs.rm("/Volumes/workspace/default/amazon_fullfilment/source", True)

# %%
# cleanup bronze
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/", recurse=True)
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.addresses")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.bin_events")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.customers")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.employee")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.inventory")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.order_items")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.orders")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.products")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.robot_events")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.shelves_events")

# %%
#cleanup silver
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_silver/processing_zone/", True)
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.address_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.bins")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.customer_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.employee")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.inventory_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.order_items_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.orders_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.products_silver")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.robots")
spark.sql("DROP TABLE workspace.amazon_fullfilment_silver.shelves")

# %%
# %run ./Initial_setup_Amazon_create_tables

# %%
# %run ./Bronze_generate_data_slower_datasets

# %%
# %skip
# %run ./Initial_setup_Amazon_populate_tables
