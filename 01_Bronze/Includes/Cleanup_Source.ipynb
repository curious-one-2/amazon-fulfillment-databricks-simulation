# %% [markdown]
# Cleaning up the source files

# %%
dbutils.fs.rm("/Volumes/workspace/default/amazon_fullfilment/source", True)

# %%
# check
df = dbutils.fs.ls("/Volumes/workspace/default/amazon_fullfilment/source")
print(df)
