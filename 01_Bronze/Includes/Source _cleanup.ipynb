# %% [markdown]
# Clean up the source files and directories

# %%
volume_path ="/Volumes/workspace/default/amazon_fullfilment/source/"

# %%
dbutils.fs.rm(f'{volume_path}', True)

# %% [markdown]
# Check ...

# %%
df = dbutils.fs.ls(volume_path)
display(df)

# %%
dbutils.fs.rm("/Volumes/workspace/default/amazon_fullfilment/source/order_items", True)
