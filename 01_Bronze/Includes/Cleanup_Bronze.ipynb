# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/", recurse=True)
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.addresses")
#spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.bin_event")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.bin_events")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.customers")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.employee")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.inventory")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.order_items")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.orders")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.products")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.robot_events")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.shelves_events")
#spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.shipment")

# %%
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.addresses")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.customers")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.products")

# %%
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.employee")
spark.sql("DROP TABLE workspace.amazon_fullfilment_bronze.shelves_events")

# %%
dbutils.fs.ls("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/")

# %%
# %sql
DROP TABLE workspace.amazon_fullfilment_bronze.orders;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/orders", recurse=True)

# %%
# %sql
DROP TABLE workspace.amazon_fullfilment_bronze.order_items;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/order_items", recurse=True)

# %%
# %sql
DROP TABLE workspace.amazon_fullfilment_bronze.shelves;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/shelves", recurse=True)

# %%
# %sql
drop table workspace.amazon_fullfilment_bronze.inventory;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/inventory", recurse=True)

# %%
# %sql
drop table workspace.amazon_fullfilment_bronze.robot_events;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/robot_events", recurse=True)

# %%
# %sql
drop table workspace.amazon_fullfilment_bronze.bin;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/bin", recurse=True)

# %%
# %sql
drop table workspace.amazon_fullfilment_bronze.bin_event;

# %%
dbutils.fs.rm("/Volumes/workspace/amazon_fullfilment_bronze/landing_zone/bin_event", recurse=True)
